# %%
#Libs Necessárias

#Libs para Modelagem e Matrizez
import numpy as np
import pandas as pd

#Libs para anaálises gráficas
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

#Lib para ignorar avisos
import warnings

#Desabilitando avisos
warnings.filterwarnings('ignore')

# %%
#Leitura da base de dados
base_dados = pd.read_csv('nflx_stock_data2.csv')

#Verificando os dados
base_dados.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2023-05-05  323.609985  324.149994  319.440002  322.760010  322.760010
# 1  2023-05-08  322.989990  332.559998  322.029999  331.209991  331.209991
# 2  2023-05-09  330.670013  336.320007  329.739990  332.140015  332.140015
# 3  2023-05-10  335.209991  337.109985  329.510010  335.420013  335.420013
# 4  2023-05-11  334.980011  345.470001  331.839996  344.760010  344.760010
#
#     Volume
# 0  3988600
# 1  5488600
# 2  5544900
# 3  4289900
# 4  8033500

# %%
#Criando um gráfico candle
grafico = go.Figure(
    data= [
        go.Candlestick(
            x= base_dados['Date'],
            open= base_dados['Open'],
            high= base_dados['High'],
            low= base_dados['Low'],
            close= base_dados['Close']
        )
      ]
    )

#Adicionando título e nomeando os eixos x e y
grafico.update_layout(
    title= 'Dados das Ações da Netflix em 2023',
    xaxis_title= 'Data',
    yaxis_title= 'Preço',
    xaxis_rangeslider_visible= False
)

#Mostrando o gráfico
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
